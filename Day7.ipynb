# %% [markdown]
# # Day 7

# %% [markdown]
# 1. Given a string of odd length greater than 7, return a new string made of the middle three characters
# of a given String
# Given:
# str1 = "RakeshzipPetabb"
# Output
# zip
# str2 = "JazzbonAyxx"
# Output
# bon

# %%
str1 = input("Enter a name: ")
a=len(str1)-3
b=a//2
str1[b:b+3]
# Out:
# Enter a name: JazzbonAyxx
# 'bon'

# %% [markdown]
# 2. Given two strings, s1 and s2, create a new string by appending s2 in the middle of s1
# Given:
# s1 = "Ault"
# s2 = "Kelly"
# Expected Output:
# AuKellylt

# %%
s1, s2 = input("Enter 2 strings : ").split()
s3 = s1[:len(s1)//2]+s2+s1[len(s1)//2:]
s3
# Out:
# Enter 2 strings : appending middle
# 'appemiddlending'

# %% [markdown]
# 3. two strings, s1, and s2 return a new string made of the first, middle, and last characters each input
# string
# Given:
# s1 = "America"
# s2 = "Japan"
# Expected Output:
# AJrpan

# %%
s1 = "America"
s2 = "Japan"
mid1= len(s1)//2 
mid2= len(s2)//2 
s3 = s1[0] + s2[0] + s1[mid1] + s2[mid2] + s1[-1] + s2[-1]
s3
# Out:
# 'AJrpan'

# %% [markdown]
# 4. Given an input string with the combination of the lower and upper case arrange characters in such a
# way that all lowercase letters should come first.

# %%
s=input("Enter a string : ")
new=[ele for ele in s if ele.islower()]
new=new + [elem for elem in s if elem.isupper()]
new= "".join(new)
print(new)
# Out:
# Enter a string : AsDfGh
# sfhADG

# %% [markdown]
# 5. create a third-string made of the first char of s1 then the last char of s2, Next, the second char of s1
# and second last char of s2, and so on. Any leftover chars go at the end of the result.
# Given:
# s1 = "Abc"
# s2 = "Xyz"
# Expected Output:
# AzbycX

# %%
s1 = "Abc"
s2 = "Xyz"
s2=s2[::-1]
s3 = [e1+e2 for e1,e2 in zip(s1,s2)]
print(''.join(s3))
# Out:
# AzbycX

# %% [markdown]
# 6. Find all occurrences of “USA” from right to left in a given string ignoring the case. also display the
# starting position
# Given:
# str1 = "Welcome to USA. usa awesome, isn't it?
# Expected answer : 16, 11

# %%
string = input("Enter a string :")
substring = input("Enter substring : ")
substring_l = substring.lower()
substring_u = substring.upper()
len_sub=len(substring)
count=0
l1=[]
for i in range(len(string)):
    if string[i:i+len_sub]==substring_l or string[i:i+len_sub]==substring_u:
        l1.append(str(i))
l1=l1[::-1]
print("The count is : ", " ".join(l1))
# Out:
# Enter a string :Welcome to USA. usa awesome, isn't it?
# Enter substring : usa
# The count is :  16 11

# %% [markdown]
# 7. Find all overlapping occurrences of given substring in given string
# Ex.
# String = 0111
# Substring = 11
# Expected answer : 2
# String : ANANAAAANNN
# Substring: ANA
# Expected answer : 2
# String : ANANAAAANNN
# Substring: AA
# Expected answer : 3

# %%
string = input("Enter a string :")
substring = input("Enter substring : ")
len_sub=len(substring)
count=0
for i in range(len(string)):
    if string[i:i+len_sub]==substring:
        count+=1
print("The count is : ", count)
# Out:
# Enter a string : ANANAAAANNN
# Enter substring : aa
# The count is :  0

# %% [markdown]
# Use of find()

# %%
word = 'geeks for geeks'

# Substring is searched in 'eks for geeks'
print(word.find('ge', 2))

# Substring is searched in 'eks for geeks'
print(word.rfind('geeks ', 2))

# Substring is searched in 's for g'
print(word.find('g', 4, 10))

# Substring is searched in 's for g'
print(word.find('for ', 4, 11))
# Out:
# 10
# -1
# -1
# 6

# %% [markdown]
# 8. Given a string in format Emp_name:Emp_id
# If emp_is is perfect square -- > Print only vowels from emp_name
# Else if emp_id is prime -- > print alternate characters from emp_name
# Else if emp_id is odd -- > print sum of ascii values of characters in emp_name
# Else print None

# %%
import math
import sympy
n, i = input("Enter  Emp_name, Emp_id: ").split()
i=int(i)
sq=math.ceil(math.sqrt(i))
#l_asc=[]
# type(sq)
vowels={'a','e','i','o','u'}
a={*n}
if i%sq==0:
    print(a & vowels)
elif (sympy.isprime(i)==True):
    print(n[:len(n):2])
elif (i%2!=0):
    l_asc=[ord(ele) for ele in n]
    print(l_asc)
else:
    print(print()) #print() returns None

# %% [markdown]
# 9. Find all mobile number mentioned in given paragraph of text
# Mobile number is always a 10 digit number no spaces no special characters
# Ex. Input= “this is a good number 9089786756 and 8900000000 is a desired number”
# Expected output: 9089786756 , 8900000000

# %%
n=input("Enter sentence : ").split()
for i in n:
    if (i.isdigit()) and (len(i)==10):
        print(i)
# Out:
# Enter sentence : this is a good number 9089786756 and 8900000000 is a desired number 4754 1654 4444444444
# 9089786756
# 8900000000
# 4444444444

# %% [markdown]
# 11. Given a paragraph count number of words, sentences. Every sentence ends with either . or ? or !
# Print Count of how many normal sentences ending with . , how many interrogative sentences ( ending
# with ?) and how many exclamatory sentences ( ending with !).
# Ex.
# Input : “I am at CDAC. What about you? I am surprised by current weather!”
# Normal sentence : 1
# Interrogative: 1
# Exclamatory : 1

# %%
n=input("Enter sentence : ")
normal=0
inter=0
excla=0
for ele in n:
    if ele == '.':
        normal+=1
    elif ele == '?':
        inter+=1
    elif ele == '!':
        excla+=1
print("Normal sentence : ",normal)
print("Interrogative sentence : ",inter)
print("Exclamatory sentence : ",excla)
# Out:
# Enter sentence : I am at CDAC. What about you? I am surprised by current weather!
# Normal sentence :  1
# Interrogative sentence :  1
# Exclamatory sentence :  1

# %% [markdown]
# 12. You are given a string S and width w.
# Your task is to wrap the string into a paragraph of width w
# Example .
# String : “ABCDEFGHIJKLIMNOQRSTUVWXYZ”
# Width: 4
# Output:
# ABCD
# EFGH
# IJKL
# IMNO
# QRST
# UVWX
# YZ

# %%
import textwrap
s=input("Enter a string : ")
wrap_list = textwrap.wrap(s,4)
for ele in wrap_list:
    print(ele)
# Out:
# Enter a string : ABCDEFGHIJKLIMNOQRSTUVWXYZ
# ABCD
# EFGH
# IJKL
# IMNO
# QRST
# UVWX
# YZ
